# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
data = pd.read_csv("Iris.csv")
iris_df = pd.DataFrame(data)
iris_df
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# ..                   ...             ...
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
iris_df.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
iris_df.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
iris_df.tail(10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
print(iris_df.shape)
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
indices=iris_df.index.values
cols=iris_df.columns
if('index' in cols):
    print('index column already exists, deleting it')
    del iris_df['index']
print('Adding Index as first column')
iris_df.insert(0,'index',indices)
iris_df
# Out:
# index column already exists, deleting it
# Adding Index as first column
#      index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0        0                   5.1                  3.5                   1.4
# 1        1                   4.9                  3.0                   1.4
# 2        2                   4.7                  3.2                   1.3
# 3        3                   4.6                  3.1                   1.5
# 4        4                   5.0                  3.6                   1.4
# ..     ...                   ...                  ...                   ...
# 145    145                   6.7                  3.0                   5.2
# 146    146                   6.3                  2.5                   5.0
# 147    147                   6.5                  3.0                   5.2
# 148    148                   6.2                  3.4                   5.4
# 149    149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# ..                   ...             ...
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#deleting index as first column
#cols=iris_df.columns
#if('index' in cols):
#    print('index column already exists, deleting it')
#    del iris_df['index']
#iris_df

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
#This is considering the newly added index cloumn as the first column
iris_df.iloc[:,2:3]
# Out:
#      Sepal Width in (cm)
# 0                    3.5
# 1                    3.0
# 2                    3.2
# 3                    3.1
# 4                    3.6
# ..                   ...
# 145                  3.0
# 146                  2.5
# 147                  3.0
# 148                  3.4
# 149                  3.0
#
# [150 rows x 1 columns]

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
#iris_df.iloc[0:10,1:3]
iris_df[['Sepal Width in (cm)','Sepal Length (in cm)']].head(10)
# Out:
#    Sepal Width in (cm)  Sepal Length (in cm)
# 0                  3.5                   5.1
# 1                  3.0                   4.9
# 2                  3.2                   4.7
# 3                  3.1                   4.6
# 4                  3.6                   5.0
# 5                  3.9                   5.4
# 6                  3.4                   4.6
# 7                  3.4                   5.0
# 8                  2.9                   4.4
# 9                  3.1                   4.9

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
iris_df.loc[data['Class'] == 'Iris-setosa']
# Out:
#     index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0       0                   5.1                  3.5                   1.4
# 1       1                   4.9                  3.0                   1.4
# 2       2                   4.7                  3.2                   1.3
# 3       3                   4.6                  3.1                   1.5
# 4       4                   5.0                  3.6                   1.4
# 5       5                   5.4                  3.9                   1.7
# 6       6                   4.6                  3.4                   1.4
# 7       7                   5.0                  3.4                   1.5
# 8       8                   4.4                  2.9                   1.4
# 9       9                   4.9                  3.1                   1.5
# 10     10                   5.4                  3.7                   1.5
# 11     11                   4.8                  3.4                   1.6
# 12     12                   4.8                  3.0                   1.4
# 13     13                   4.3                  3.0                   1.1
# 14     14                   5.8                  4.0                   1.2
# 15     15                   5.7                  4.4                   1.5
# 16     16                   5.4                  3.9                   1.3
# 17     17                   5.1                  3.5                   1.4
# 18     18                   5.7                  3.8                   1.7
# 19     19                   5.1                  3.8                   1.5
# 20     20                   5.4                  3.4                   1.7
# 21     21                   5.1                  3.7                   1.5
# 22     22                   4.6                  3.6                   1.0
# 23     23                   5.1                  3.3                   1.7
# 24     24                   4.8                  3.4                   1.9
# 25     25                   5.0                  3.0                   1.6
# 26     26                   5.0                  3.4                   1.6
# 27     27                   5.2                  3.5                   1.5
# 28     28                   5.2                  3.4                   1.4
# 29     29                   4.7                  3.2                   1.6
# 30     30                   4.8                  3.1                   1.6
# 31     31                   5.4                  3.4                   1.5
# 32     32                   5.2                  4.1                   1.5
# 33     33                   5.5                  4.2                   1.4
# 34     34                   4.9                  3.1                   1.5
# 35     35                   5.0                  3.2                   1.2
# 36     36                   5.5                  3.5                   1.3
# 37     37                   4.9                  3.1                   1.5
# 38     38                   4.4                  3.0                   1.3
# 39     39                   5.1                  3.4                   1.5
# 40     40                   5.0                  3.5                   1.3
# 41     41                   4.5                  2.3                   1.3
# 42     42                   4.4                  3.2                   1.3
# 43     43                   5.0                  3.5                   1.6
# 44     44                   5.1                  3.8                   1.9
# 45     45                   4.8                  3.0                   1.4
# 46     46                   5.1                  3.8                   1.6
# 47     47                   4.6                  3.2                   1.4
# 48     48                   5.3                  3.7                   1.5
# 49     49                   5.0                  3.3                   1.4
#
#     Petal width (in cm)        Class
# 0                   0.2  Iris-setosa
# 1                   0.2  Iris-setosa
# 2                   0.2  Iris-setosa
# 3                   0.2  Iris-setosa
# 4                   0.2  Iris-setosa
# 5                   0.4  Iris-setosa
# 6                   0.3  Iris-setosa
# 7                   0.2  Iris-setosa
# 8                   0.2  Iris-setosa
# 9                   0.1  Iris-setosa
# 10                  0.2  Iris-setosa
# 11                  0.2  Iris-setosa
# 12                  0.1  Iris-setosa
# 13                  0.1  Iris-setosa
# 14                  0.2  Iris-setosa
# 15                  0.4  Iris-setosa
# 16                  0.4  Iris-setosa
# 17                  0.3  Iris-setosa
# 18                  0.3  Iris-setosa
# 19                  0.3  Iris-setosa
# 20                  0.2  Iris-setosa
# 21                  0.4  Iris-setosa
# 22                  0.2  Iris-setosa
# 23                  0.5  Iris-setosa
# 24                  0.2  Iris-setosa
# 25                  0.2  Iris-setosa
# 26                  0.4  Iris-setosa
# 27                  0.2  Iris-setosa
# 28                  0.2  Iris-setosa
# 29                  0.2  Iris-setosa
# 30                  0.2  Iris-setosa
# 31                  0.4  Iris-setosa
# 32                  0.1  Iris-setosa
# 33                  0.2  Iris-setosa
# 34                  0.1  Iris-setosa
# 35                  0.2  Iris-setosa
# 36                  0.2  Iris-setosa
# 37                  0.1  Iris-setosa
# 38                  0.2  Iris-setosa
# 39                  0.2  Iris-setosa
# 40                  0.3  Iris-setosa
# 41                  0.3  Iris-setosa
# 42                  0.2  Iris-setosa
# 43                  0.6  Iris-setosa
# 44                  0.4  Iris-setosa
# 45                  0.3  Iris-setosa
# 46                  0.2  Iris-setosa
# 47                  0.2  Iris-setosa
# 48                  0.2  Iris-setosa
# 49                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
sepal_extra=iris_df['Sepal Length (in cm)']*iris_df['Sepal Width in (cm)']
iris_df['SepalExtra'] = sepal_extra
iris_df
# Out:
#      index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0        0                   5.1                  3.5                   1.4
# 1        1                   4.9                  3.0                   1.4
# 2        2                   4.7                  3.2                   1.3
# 3        3                   4.6                  3.1                   1.5
# 4        4                   5.0                  3.6                   1.4
# ..     ...                   ...                  ...                   ...
# 145    145                   6.7                  3.0                   5.2
# 146    146                   6.3                  2.5                   5.0
# 147    147                   6.5                  3.0                   5.2
# 148    148                   6.2                  3.4                   5.4
# 149    149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class  SepalExtra
# 0                    0.2     Iris-setosa       17.85
# 1                    0.2     Iris-setosa       14.70
# 2                    0.2     Iris-setosa       15.04
# 3                    0.2     Iris-setosa       14.26
# 4                    0.2     Iris-setosa       18.00
# ..                   ...             ...         ...
# 145                  2.3  Iris-virginica       20.10
# 146                  1.9  Iris-virginica       15.75
# 147                  2.0  Iris-virginica       19.50
# 148                  2.3  Iris-virginica       21.08
# 149                  1.8  Iris-virginica       17.70
#
# [150 rows x 7 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
#mean of all numeric columns
iris_df.mean(axis=0)
# Out:
# index                   74.500000
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64

# %%
#variance of all numeric columns
iris_df.var(axis=0)
# Out:
# index                   1887.500000
# Sepal Length (in cm)       0.685694
# Sepal Width in (cm)        0.188004
# Petal length (in cm)       3.113179
# Petal width (in cm)        0.582414
# SepalExtra                11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def print_data(sepal_length,sepal_width):
    print('sepal_length is:', sepal_length)
    print('sepal_width is:', sepal_width)
    
sepal_length = iris_df.iloc[4]['Sepal Length (in cm)']
sepal_width = iris_df.iloc[4]['Sepal Width in (cm)']
print_data(sepal_length,sepal_width)
# Out:
# sepal_length is: 5.0
# sepal_width is: 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
# Method:1
# cols=df.columns
# for c in cols:
#     if(c!='Class'):
#         print(df[c].max()-df[c].min())

#Method:2
df=iris_df
df=df.drop(['Class'],axis=1)
df.max()-df.min()
# Out:
# index                   149.00
# Sepal Length (in cm)      3.60
# Sepal Width in (cm)       2.40
# Petal length (in cm)      5.90
# Petal width (in cm)       2.40
# SepalExtra               20.02
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
iris_df.sort_values('Petal width (in cm)', axis=0, ascending=True, inplace=False,na_position='last')
# Out:
#      index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32      32                   5.2                  4.1                   1.5
# 13      13                   4.3                  3.0                   1.1
# 37      37                   4.9                  3.1                   1.5
# 9        9                   4.9                  3.1                   1.5
# 12      12                   4.8                  3.0                   1.4
# ..     ...                   ...                  ...                   ...
# 140    140                   6.7                  3.1                   5.6
# 114    114                   5.8                  2.8                   5.1
# 100    100                   6.3                  3.3                   6.0
# 144    144                   6.7                  3.3                   5.7
# 109    109                   7.2                  3.6                   6.1
#
#      Petal width (in cm)           Class
# 32                   0.1     Iris-setosa
# 13                   0.1     Iris-setosa
# 37                   0.1     Iris-setosa
# 9                    0.1     Iris-setosa
# 12                   0.1     Iris-setosa
# ..                   ...             ...
# 140                  2.4  Iris-virginica
# 114                  2.4  Iris-virginica
# 100                  2.5  Iris-virginica
# 144                  2.5  Iris-virginica
# 109                  2.5  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
iris_df.drop(['SepalExtra'],axis=1,inplace=True)
iris_df
# Out:
#      index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0        0                   5.1                  3.5                   1.4
# 1        1                   4.9                  3.0                   1.4
# 2        2                   4.7                  3.2                   1.3
# 3        3                   4.6                  3.1                   1.5
# 4        4                   5.0                  3.6                   1.4
# ..     ...                   ...                  ...                   ...
# 145    145                   6.7                  3.0                   5.2
# 146    146                   6.3                  2.5                   5.0
# 147    147                   6.5                  3.0                   5.2
# 148    148                   6.2                  3.4                   5.4
# 149    149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# ..                   ...             ...
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset=iris_df.iloc[:,0:3]
IrisSubset.head(10)
# Out:
#    index  Sepal Length (in cm)  Sepal Width in (cm)
# 0      0                   5.1                  3.5
# 1      1                   4.9                  3.0
# 2      2                   4.7                  3.2
# 3      3                   4.6                  3.1
# 4      4                   5.0                  3.6
# 5      5                   5.4                  3.9
# 6      6                   4.6                  3.4
# 7      7                   5.0                  3.4
# 8      8                   4.4                  2.9
# 9      9                   4.9                  3.1

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
hr=pd.read_csv('HR_external.txt', sep='\t')
hr
# Out:
#      Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0           Ind1       Yes   41               1       1102           1
# 1           Ind2        No   49               2        279           2
# 2           Ind3       Yes   37               1       1373           2
# 3           Ind4        No   33               2       1392           2
# 4           Ind5        No   27               1        591           2
# ...          ...       ...  ...             ...        ...         ...
# 1465     Ind1466        No   36               2        884           2
# 1466     Ind1467        No   39               1        613           2
# 1467     Ind1468        No   27               1        155           2
# 1468     Ind1469        No   49               2       1023           1
# 1469     Ind1470        No   34               1        628           2
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                    1          2               1              1  ...
# 1                    8          1               1              1  ...
# 2                    2          2               6              1  ...
# 3                    3          4               1              1  ...
# 4                    2          1               2              1  ...
# ...                ...        ...             ...            ...  ...
# 1465                23          2               2              1  ...
# 1466                 6          1               2              1  ...
# 1467                 4          3               1              1  ...
# 1468                 2          3               2              1  ...
# 1469                 8          3               2              1  ...
#
#       RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                            1             80                 0
# 1                            4             80                 1
# 2                            2             80                 0
# 3                            3             80                 0
# 4                            4             80                 1
# ...                        ...            ...               ...
# 1465                         3             80                 1
# 1466                         1             80                 1
# 1467                         2             80                 1
# 1468                         4             80                 0
# 1469                         1             80                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
#No. of rows and columns 
print(hr.shape)
# Out:
# (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
print(hr.dtypes)
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
hr.iloc[:,2:10]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               2        884           2                23          2
# 1466   39               1        613           2                 6          1
# 1467   27               1        155           2                 4          3
# 1468   49               2       1023           1                 2          3
# 1469   34               1        628           2                 8          3
#
#       EducationField  EmployeeCount
# 0                  1              1
# 1                  1              1
# 2                  6              1
# 3                  1              1
# 4                  2              1
# ...              ...            ...
# 1465               2              1
# 1466               2              1
# 1467               1              1
# 1468               2              1
# 1469               2              1
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
male_count=len(hr.loc[hr['Gender']==2])
print("No. of males:", male_count)
female_count=len(hr.loc[hr['Gender']==1])
print("No. of females:", female_count)
# Out:
# No. of males: 588
# No. of females: 882

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
hr['Age']
quantile_25=hr['Age'].quantile(0.25)
print("25th percentile",quantile_25)
quantile_75=hr['Age'].quantile(0.75)
print("75th percentile",quantile_75)
print('IQR is :', quantile_75-quantile_25)
# Out:
# 25th percentile 30.0
# 75th percentile 43.0
# IQR is : 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
mean=hr['DailyRate'].mean()
median=hr['DailyRate'].median()
variance=hr['DailyRate'].var()

print('median is:', median)
print('mean is :', mean)
print('variance is:', variance)
# Out:
# median is: 802.0
# mean is : 802.4857142857143
# variance is: 162819.5937372362

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
#pip install seaborn

# %%
import seaborn as sns
sns.countplot(hr['Attrition'])

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
import matplotlib.pyplot as plt
hr[['TotalWorkingYears']].plot(kind='hist',bins=[0,10,20,30,40,50,60],rwidth=0.8)
plt.show()
